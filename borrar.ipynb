# %%
import matplotlib.pyplot as plt
n,m = 3000,2500
n_selected_betas = [51.0, 44.0, 27.0, 24.0, 22.0, 16.0, 10.0, 9.0, 9.0, 8.0, 8.0, 6.0, 6.0, 5.0, 3.0]
model_errors = [2142.397431844468, 3031.4793734147815, 4240.695902742735, 5222.840640923261, 7280.636748533568, 9808.417013235201, 12139.49453062819, 12992.24575181646, 13136.817693126306, 13707.620285100431, 15859.300104237618, 22708.06303413142, 40055.623824878785, 76289.66888187933, 149422.18472735994]
times = [0.4489594956239064, 0.46877546469370523, 0.7232081190745036, 0.6482047824064889, 0.5104939540227253, 0.44469936291376755, 0.4509389205773672, 0.4515752788384756, 0.42519657572110486, 0.4539235691229503, 0.49643919507662454, 0.47841236114501956, 0.41525033871332806, 0.5826883363723756, 0.5757466006278992]

 # Plot times in terms of number of selected betas
plt.figure(figsize=(12, 6))
plt.plot(n_selected_betas, times)
# add gray background to plot
plt.axvspan(0, 50, facecolor='gray', alpha=0.2)
plt.xlabel('Number of selected betas')
plt.ylabel('Time (s)')
plt.title('Time vs. number of selected betas (n, m = {}, {})'.format(n, m))
plt.show()

# Plot model errors in terms of number of selected betas
plt.figure(figsize=(12, 6))
plt.plot(n_selected_betas, model_errors)
plt.xlabel('Number of selected betas')
plt.ylabel('Model error (RMSE)')
plt.title('Model error vs. number of selected betas (n, m = {}, {})'.format(n, m))
plt.show()
